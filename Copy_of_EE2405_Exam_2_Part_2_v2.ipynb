# %% [markdown]
# # EE2405 Embedded System Lab Exam #2 Part 2
#
# **Please click on "Open in playground" at the upper-left corner to create a copy for you.**
#
# ---
#
# **Please fill in correct statements in the right of the codes to finish the scripts.**
# Data sample is generated with a quadratic function and we will train a regression model to fit the data.
# And we convert and interpret the trained model with a Tensorflow lite APIs.
#
# You can run the script again after you fill all the blank to check the outputs.
#
# ---
#
# The Method to Download the Jupyter Notebook:
# File > Download .ipynb

# %% [markdown]
# ## Import dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf
# Numpy is a math library
import numpy as np
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# math is Python's math library
import math

# %% [markdown]
# ## Generate Data

# %%
# We'll generate this many sample datapoints
############################################################
#@markdown Please fill in the number of samples (the sample should be large enough, but not too large for computation).
SAMPLES =  200#@param {type:"number"}
############################################################


############################################################
#@markdown Please fill in your student id, which is the random seed.
student_id = 107000129 #@param {type:"number"}
np.random.seed(student_id)
############################################################

# Generate a uniformly distributed set of random numbers
# in the range from 0 to 10
x_values = np.random.uniform(low=0, high=10, size=SAMPLES)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

############################################################
#@markdown Please fill in the statement to generate `y_values` with a quadratic function `y = x^2-5x+1`?
script = "y_values = x_values*x_values-5*x_values+1" #@param {type:"string"}
exec(script)
############################################################

# Plot our data.
# The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Add some noise

# %%
# Add a small random number to each y value
y_values += np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Split our data

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Design a model

# %%
# We'll use Keras to create a simple model architecture
from tensorflow.keras import layers
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model.add(layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ## Train the model

# %%
# Train the model on our training data while validating on our validation set
model.fit(x_train, y_train, epochs=1000, batch_size=16,
          validation_data=(x_validate, y_validate))

print("Done!")
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 368.5269 - mae: 12.7427 - val_loss: 272.8897 - val_mae: 11.8268
# Epoch 2/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 336.6348 - mae: 12.5956 - val_loss: 267.7410 - val_mae: 11.7331
# Epoch 3/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 343.0876 - mae: 12.5067 - val_loss: 262.7804 - val_mae: 11.6412
# Epoch 4/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 317.7256 - mae: 12.4150 - val_loss: 258.5219 - val_mae: 11.5612
# Epoch 5/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 306.6510 - mae: 12.3346 - val_loss: 254.4821 - val_mae: 11.4865
# Epoch 6/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 316.8069 - mae: 12.2598 - val_loss: 250.1874 - val_mae: 11.4096
# Epoch 7/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 312.4092 - mae: 12.1849 - val_loss: 246.8344 - val_mae: 11.3503
# Epoch 8/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 290.5030 - mae: 12.1253 - val_loss: 243.9052 - val_mae: 11.2957
# Epoch 9/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 308.0664 - mae: 12.0713 - val_loss: 240.7482 - val_mae: 11.2403
# Epoch 10/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 282.0613 - mae: 12.0153 - val_loss: 237.8621 - val_mae: 11.1868
# Epoch 11/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 283.3292 - mae: 11.9593 - val_loss: 234.9875 - val_mae: 11.1329
# Epoch 12/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 292.6257 - mae: 11.9037 - val_loss: 232.0154 - val_mae: 11.0790
# Epoch 13/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 277.5249 - mae: 11.8528 - val_loss: 229.2222 - val_mae: 11.0254
# Epoch 14/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 266.8248 - mae: 11.7993 - val_loss: 226.5116 - val_mae: 10.9739
# Epoch 15/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 282.0029 - mae: 11.7485 - val_loss: 223.5795 - val_mae: 10.9161
# Epoch 16/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 268.0715 - mae: 11.6964 - val_loss: 220.8302 - val_mae: 10.8649
# Epoch 17/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 262.5045 - mae: 11.6495 - val_loss: 217.9337 - val_mae: 10.8097
# Epoch 18/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 279.8002 - mae: 11.5885 - val_loss: 214.8112 - val_mae: 10.7546
# Epoch 19/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 6ms/step - loss: 100.4941 - mae: 8.7770 - val_loss: 101.9690 - val_mae: 8.9455
# Epoch 85/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 103.4677 - mae: 8.7692 - val_loss: 101.4911 - val_mae: 8.9227
# Epoch 86/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 102.2353 - mae: 8.7346 - val_loss: 101.3677 - val_mae: 8.9105
# Epoch 87/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 102.3269 - mae: 8.7373 - val_loss: 100.9660 - val_mae: 8.8897
# Epoch 88/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.3363 - mae: 8.7124 - val_loss: 100.8406 - val_mae: 8.8787
# Epoch 89/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 99.7067 - mae: 8.6989 - val_loss: 100.4195 - val_mae: 8.8561
# Epoch 90/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 104.6310 - mae: 8.6769 - val_loss: 100.3754 - val_mae: 8.8508
# Epoch 91/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 97.7924 - mae: 8.6647 - val_loss: 99.9076 - val_mae: 8.8261
# Epoch 92/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 96.7127 - mae: 8.6228 - val_loss: 99.8110 - val_mae: 8.8186
# Epoch 93/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 97.9856 - mae: 8.6286 - val_loss: 99.5458 - val_mae: 8.8027
# Epoch 94/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 99.4051 - mae: 8.6093 - val_loss: 99.7299 - val_mae: 8.8051
# Epoch 95/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 97.6239 - mae: 8.6003 - val_loss: 99.3268 - val_mae: 8.7845
# Epoch 96/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 94.2739 - mae: 8.5809 - val_loss: 98.6457 - val_mae: 8.7506
# Epoch 97/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 96.5035 - mae: 8.5510 - val_loss: 98.3897 - val_mae: 8.7347
# Epoch 98/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 97.1197 - mae: 8.5268 - val_loss: 98.8396 - val_mae: 8.7465
# Epoch 99/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 96.9505 - mae: 8.5334 - val_loss: 98.2346 - val_mae: 8.7184
# Epoch 100/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 95.1796 - mae: 8.5050 - val_loss: 97.6376 - val_mae: 8.6887
# Epoch 101/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 95.0678 - mae: 8.4816 - val_loss: 97.7158 - val_mae: 8.6864
# Epoch 102/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 94.5510 - mae: 8.4646 - val_loss: 97.2869 - val_mae: 8.6637
# Epoch 103/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 95.4479 - mae: 8.4567 - val_loss: 96.5991 - val_mae: 8.6303
# Epoch 104/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 93.1586 - mae: 8.4263 - val_loss: 96.4183 - val_mae: 8.6178
# Epoch 105/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 95.6424 - mae: 8.4149 - val_loss: 96.1412 - val_mae: 8.6010
# Epoch 106/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.6755 - mae: 8.3908 - val_loss: 95.9710 - val_mae: 8.5884
# Epoch 107/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.8869 - mae: 8.3647 - val_loss: 94.9398 - val_mae: 8.5422
# Epoch 108/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 93.4216 - mae: 8.3309 - val_loss: 94.7147 - val_mae: 8.5292
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.4606 - mae: 8.3234 - val_loss: 94.7382 - val_mae: 8.5263
# Epoch 110/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 93.9089 - mae: 8.3153 - val_loss: 94.6259 - val_mae: 8.5166
# Epoch 111/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 91.5778 - mae: 8.3018 - val_loss: 94.1476 - val_mae: 8.4928
# Epoch 112/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 90.0905 - mae: 8.2737 - val_loss: 93.6405 - val_mae: 8.4675
# Epoch 113/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 90.2810 - mae: 8.2514 - val_loss: 92.7178 - val_mae: 8.4251
# Epoch 114/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 88.0134 - mae: 8.2256 - val_loss: 92.5150 - val_mae: 8.4127
# Epoch 115/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 88.4153 - mae: 8.2099 - val_loss: 92.0213 - val_mae: 8.3874
# Epoch 116/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 5ms/step - loss: 49.3244 - mae: 5.7448 - val_loss: 52.0771 - val_mae: 6.1118
# Epoch 213/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 46.9612 - mae: 5.7182 - val_loss: 51.1837 - val_mae: 6.0522
# Epoch 214/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 49.6825 - mae: 5.6509 - val_loss: 51.3078 - val_mae: 6.0644
# Epoch 215/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 47.0059 - mae: 5.6428 - val_loss: 50.3240 - val_mae: 5.9945
# Epoch 216/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 47.5020 - mae: 5.6130 - val_loss: 49.8843 - val_mae: 5.9645
# Epoch 217/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 47.8888 - mae: 5.5627 - val_loss: 50.3142 - val_mae: 6.0015
# Epoch 218/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 45.0923 - mae: 5.5687 - val_loss: 49.8651 - val_mae: 5.9708
# Epoch 219/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 45.6691 - mae: 5.5340 - val_loss: 49.1407 - val_mae: 5.9196
# Epoch 220/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 46.0974 - mae: 5.5113 - val_loss: 48.8484 - val_mae: 5.9016
# Epoch 221/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 45.5659 - mae: 5.4791 - val_loss: 47.9431 - val_mae: 5.8325
# Epoch 222/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 47.0612 - mae: 5.4338 - val_loss: 48.2610 - val_mae: 5.8644
# Epoch 223/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 44.5127 - mae: 5.4131 - val_loss: 47.8462 - val_mae: 5.8368
# Epoch 224/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 44.7026 - mae: 5.4010 - val_loss: 46.8692 - val_mae: 5.7644
# Epoch 225/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 42.8894 - mae: 5.3495 - val_loss: 46.2905 - val_mae: 5.7221
# Epoch 226/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 46.5910 - mae: 5.3206 - val_loss: 46.4470 - val_mae: 5.7406
# Epoch 227/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 42.0484 - mae: 5.3331 - val_loss: 45.2444 - val_mae: 5.6466
# Epoch 228/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 42.0731 - mae: 5.2425 - val_loss: 45.5092 - val_mae: 5.6739
# Epoch 229/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 40.5847 - mae: 5.2617 - val_loss: 44.8410 - val_mae: 5.6238
# Epoch 230/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 43.0533 - mae: 5.2092 - val_loss: 45.0109 - val_mae: 5.6386
# Epoch 231/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 42.3927 - mae: 5.1942 - val_loss: 44.4582 - val_mae: 5.6001
# Epoch 232/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 42.1880 - mae: 5.1856 - val_loss: 43.8724 - val_mae: 5.5585
# Epoch 233/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 41.5009 - mae: 5.1267 - val_loss: 44.2682 - val_mae: 5.5814
# Epoch 234/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 39.4757 - mae: 5.1367 - val_loss: 42.8240 - val_mae: 5.4816
# Epoch 235/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 39.1574 - mae: 5.0467 - val_loss: 43.0305 - val_mae: 5.4960
# Epoch 236/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 38.2366 - mae: 5.0864 - val_loss: 41.9636 - val_mae: 5.4181
# Epoch 237/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 38.4533 - mae: 5.0343 - val_loss: 40.9635 - val_mae: 5.3363
# Epoch 238/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 38.4859 - mae: 4.9879 - val_loss: 40.6432 - val_mae: 5.3144
# Epoch 239/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 38.7612 - mae: 4.9605 - val_loss: 40.6965 - val_mae: 5.3238
# Epoch 240/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 37.4441 - mae: 4.9353 - val_loss: 39.9586 - val_mae: 5.2651
# Epoch 241/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 36.1777 - mae: 4.8986 - val_loss: 39.6538 - val_mae: 5.2427
# Epoch 242/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 36.8101 - mae: 4.8522 - val_loss: 39.6521 - val_mae: 5.2444
# Epoch 243/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 34.7861 - mae: 4.8316 - val_loss: 39.2621 - val_mae: 5.2141
# Epoch 244/1000
# 8/8 [==============================] - 0s 5ms/step - loss:
1000
# 8/8 [==============================] - 0s 7ms/step - loss: 11.0467 - mae: 2.5466 - val_loss: 10.9393 - val_mae: 2.5396
# Epoch 341/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.5935 - mae: 2.5340 - val_loss: 10.2892 - val_mae: 2.4708
# Epoch 342/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 11.9706 - mae: 2.4699 - val_loss: 10.8916 - val_mae: 2.5358
# Epoch 343/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 10.1664 - mae: 2.5213 - val_loss: 10.0351 - val_mae: 2.4395
# Epoch 344/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.2811 - mae: 2.4427 - val_loss: 10.0458 - val_mae: 2.4403
# Epoch 345/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.9878 - mae: 2.4560 - val_loss: 10.0069 - val_mae: 2.4291
# Epoch 346/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.4052 - mae: 2.4522 - val_loss: 9.5834 - val_mae: 2.3822
# Epoch 347/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.8109 - mae: 2.4263 - val_loss: 9.2713 - val_mae: 2.3376
# Epoch 348/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 10.2773 - mae: 2.3736 - val_loss: 9.2585 - val_mae: 2.3382
# Epoch 349/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 10.0361 - mae: 2.4036 - val_loss: 9.1773 - val_mae: 2.3268
# Epoch 350/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.8774 - mae: 2.3602 - val_loss: 9.1307 - val_mae: 2.3144
# Epoch 351/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.5808 - mae: 2.3855 - val_loss: 8.9769 - val_mae: 2.2903
# Epoch 352/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.3458 - mae: 2.3397 - val_loss: 8.9105 - val_mae: 2.2800
# Epoch 353/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.0968 - mae: 2.3147 - val_loss: 8.7305 - val_mae: 2.2555
# Epoch 354/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 9.2510 - mae: 2.2849 - val_loss: 8.7324 - val_mae: 2.2523
# Epoch 355/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 8.8413 - mae: 2.2831 - val_loss: 8.5757 - val_mae: 2.2323
# Epoch 356/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 8.9116 - mae: 2.2987 - val_loss: 8.0865 - val_mae: 2.1619
# Epoch 357/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 9.8218 - mae: 2.2384 - val_loss: 8.4816 - val_mae: 2.2217
# Epoch 358/1000
# ...
# Epoch 880/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8633 - mae: 0.7226 - val_loss: 1.1485 - val_mae: 0.8002
# Epoch 881/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7723 - mae: 0.6507 - val_loss: 1.1567 - val_mae: 0.8014
# Epoch 882/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8491 - mae: 0.6890 - val_loss: 1.1677 - val_mae: 0.8037
# Epoch 883/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7330 - mae: 0.6671 - val_loss: 1.4780 - val_mae: 0.9059
# Epoch 884/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8759 - mae: 0.6700 - val_loss: 1.4080 - val_mae: 0.8810
# Epoch 885/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7371 - mae: 0.6751 - val_loss: 1.1525 - val_mae: 0.7940
# Epoch 886/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7332 - mae: 0.6711 - val_loss: 1.4066 - val_mae: 0.9372
# Epoch 887/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8357 - mae: 0.7016 - val_loss: 1.2236 - val_mae: 0.8121
# Epoch 888/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8595 - mae: 0.7246 - val_loss: 1.1528 - val_mae: 0.7847
# Epoch 889/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7912 - mae: 0.6887 - val_loss: 1.1601 - val_mae: 0.7931
# Epoch 890/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7503 - mae: 0.6769 - val_loss: 1.1302 - val_mae: 0.7889
# Epoch 891/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8361 - mae: 0.6618 - val_loss: 1.2224 - val_mae: 0.8177
# Epoch 892/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7381 - mae: 0.6786 - val_loss: 1.3352 - val_mae: 0.9035
# Epoch 893/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8750 - mae: 0.7217 - val_loss: 1.1931 - val_mae: 0.8207
# Epoch 894/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7954 - mae: 0.6918 - val_loss: 1.1391 - val_mae: 0.7946
# Epoch 895/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7860 - mae: 0.6822 - val_loss: 1.1034 - val_mae: 0.7703
# Epoch 896/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7785 - mae: 0.7023 - val_loss: 1.1776 - val_mae: 0.8033
# Epoch 897/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7467 - mae: 0.6908 - val_loss: 1.4129 - val_mae: 0.8749
# Epoch 898/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7853 - mae: 0.7010 - val_loss: 1.1606 - val_mae: 0.7887
# Epoch 899/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7587 - mae: 0.6722 - val_loss: 1.1432 - val_mae: 0.7994
# Epoch 900/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7910 - mae: 0.6581 - val_loss: 1.6720 - val_mae: 0.9757
# Epoch 901/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8636 - mae: 0.7313 - val_loss: 1.4567 - val_mae: 0.9043
# Epoch 902/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8021 - mae: 0.7030 - val_loss: 1.2475 - val_mae: 0.8404
# Epoch 903/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7399 - mae: 0.6622 - val_loss: 1.1082 - val_mae: 0.7811
# Epoch 904/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7190 - mae: 0.6615 - val_loss: 1.1419 - val_mae: 0.7999
# Epoch 905/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8541 - mae: 0.7286 - val_loss: 1.2364 - val_mae: 0.8255
# Epoch 906/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7676 - mae: 0.6622 - val_loss: 1.1972 - val_mae: 0.8211
# Epoch 907/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7951 - mae: 0.6947 - val_loss: 1.1529 - val_mae: 0.8007
# Epoch 908/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7778 - mae: 0.6816 - val_loss: 1.1229 - val_mae: 0.7853
# Epoch 909/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8599 - mae: 0.6735 - val_loss: 1.1502 - val_mae: 0.8035
# Epoch 910/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8388 - mae: 0.6875 - val_loss: 1.1036 - val_mae: 0.7782
# Epoch 911/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7489 - mae: 0.6787 - val_loss: 1.3964 - val_mae: 0.8816
# Epoch 912/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8053 - mae: 0.6866 - val_loss: 1.0828 - val_mae: 0.7721
# Epoch 913/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7581 - mae: 0.6529 - val_loss: 1.1995 - val_mae: 0.8258
# Epoch 914/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7508 - mae: 0.6739 - val_loss: 1.7468 - val_mae: 1.0013
# Epoch 915/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8102 - mae: 0.6767 - val_loss: 1.2772 - val_mae: 0.8662
# Epoch 916/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7833 - mae: 0.7143 - val_loss: 1.1189 - val_mae: 0.7859
# Epoch 917/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7690 - mae: 0.6863 - val_loss: 1.1466 - val_mae: 0.7972
# Epoch 918/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7015 - mae: 0.6693 - val_loss: 1.1113 - val_mae: 0.7812
# Epoch 919/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8066 - mae: 0.6645 - val_loss: 1.1224 - val_mae: 0.7867
# Epoch 920/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7798 - mae: 0.7023 - val_loss: 1.0887 - val_mae: 0.7672
# Epoch 921/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7882 - mae: 0.7021 - val_loss: 1.2014 - val_mae: 0.8147
# Epoch 922/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7604 - mae: 0.6699 - val_loss: 1.1726 - val_mae: 0.8038
# Epoch 923/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7537 - mae: 0.6893 - val_loss: 1.1278 - val_mae: 0.7770
# Epoch 924/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8086 - mae: 0.6747 - val_loss: 1.1683 - val_mae: 0.7902
# Epoch 925/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8404 - mae: 0.7105 - val_loss: 1.2458 - val_mae: 0.8222
# Epoch 926/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7826 - mae: 0.7118 - val_loss: 1.1026 - val_mae: 0.7716
# Epoch 927/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7509 - mae: 0.6778 - val_loss: 1.1368 - val_mae: 0.7919
# Epoch 928/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7436 - mae: 0.6607 - val_loss: 1.2835 - val_mae: 0.8716
# Epoch 929/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7751 - mae: 0.6859 - val_loss: 1.1359 - val_mae: 0.7831
# Epoch 930/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7681 - mae: 0.6856 - val_loss: 1.3385 - val_mae: 0.8434
# Epoch 931/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8102 - mae: 0.6932 - val_loss: 1.3693 - val_mae: 0.8548
# Epoch 932/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7424 - mae: 0.6858 - val_loss: 1.1248 - val_mae: 0.7714
# Epoch 933/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7687 - mae: 0.6708 - val_loss: 1.2281 - val_mae: 0.8099
# Epoch 934/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7569 - mae: 0.6731 - val_loss: 1.0871 - val_mae: 0.7613
# Epoch 935/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7991 - mae: 0.6817 - val_loss: 1.1263 - val_mae: 0.7850
# Epoch 936/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8571 - mae: 0.7247 - val_loss: 1.1761 - val_mae: 0.8007
# Epoch 937/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8444 - mae: 0.6796 - val_loss: 1.1571 - val_mae: 0.7964
# Epoch 938/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7708 - mae: 0.6963 - val_loss: 1.0865 - val_mae: 0.7625
# Epoch 939/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7329 - mae: 0.6370 - val_loss: 1.5138 - val_mae: 0.9178
# Epoch 940/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7811 - mae: 0.6972 - val_loss: 1.2821 - val_mae: 0.8322
# Epoch 941/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7676 - mae: 0.6834 - val_loss: 1.0772 - val_mae: 0.7593
# Epoch 942/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7502 - mae: 0.6942 - val_loss: 1.0790 - val_mae: 0.7572
# Epoch 943/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7373 - mae: 0.6760 - val_loss: 1.1197 - val_mae: 0.7848
# Epoch 944/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7095 - mae: 0.6780 - val_loss: 1.1839 - val_mae: 0.8088
# Epoch 945/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7041 - mae: 0.6715 - val_loss: 1.2185 - val_mae: 0.8063
# Epoch 946/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7574 - mae: 0.6660 - val_loss: 1.1566 - val_mae: 0.7906
# Epoch 947/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8392 - mae: 0.6784 - val_loss: 1.7669 - val_mae: 1.0078
# Epoch 948/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8982 - mae: 0.6918 - val_loss: 1.2372 - val_mae: 0.8233
# Epoch 949/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7651 - mae: 0.6796 - val_loss: 1.0906 - val_mae: 0.7667
# Epoch 950/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7412 - mae: 0.7078 - val_loss: 1.1708 - val_mae: 0.8105
# Epoch 951/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7614 - mae: 0.6942 - val_loss: 1.1130 - val_mae: 0.7744
# Epoch 952/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8079 - mae: 0.6626 - val_loss: 1.0872 - val_mae: 0.7650
# Epoch 953/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7484 - mae: 0.6804 - val_loss: 1.1436 - val_mae: 0.7897
# Epoch 954/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7208 - mae: 0.6736 - val_loss: 1.3139 - val_mae: 0.8405
# Epoch 955/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8198 - mae: 0.6746 - val_loss: 1.1208 - val_mae: 0.7757
# Epoch 956/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8073 - mae: 0.7128 - val_loss: 1.1806 - val_mae: 0.8075
# Epoch 957/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7229 - mae: 0.6730 - val_loss: 1.1982 - val_mae: 0.8092
# Epoch 958/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7749 - mae: 0.7050 - val_loss: 1.1488 - val_mae: 0.7963
# Epoch 959/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8003 - mae: 0.6740 - val_loss: 1.3700 - val_mae: 0.8558
# Epoch 960/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7666 - mae: 0.7001 - val_loss: 1.0800 - val_mae: 0.7579
# Epoch 961/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8261 - mae: 0.7229 - val_loss: 1.1898 - val_mae: 0.8122
# Epoch 962/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7191 - mae: 0.6511 - val_loss: 1.4652 - val_mae: 0.8920
# Epoch 963/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8112 - mae: 0.7102 - val_loss: 1.2313 - val_mae: 0.8162
# Epoch 964/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7223 - mae: 0.6678 - val_loss: 1.4148 - val_mae: 0.8759
# Epoch 965/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7648 - mae: 0.6569 - val_loss: 1.2020 - val_mae: 0.8260
# Epoch 966/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7441 - mae: 0.6820 - val_loss: 1.1238 - val_mae: 0.7807
# Epoch 967/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7681 - mae: 0.6624 - val_loss: 1.1413 - val_mae: 0.7889
# Epoch 968/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8081 - mae: 0.6719 - val_loss: 1.4768 - val_mae: 0.9017
# Epoch 969/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7913 - mae: 0.6974 - val_loss: 1.1566 - val_mae: 0.8047
# Epoch 970/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7135 - mae: 0.6795 - val_loss: 1.5115 - val_mae: 0.9112
# Epoch 971/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7620 - mae: 0.6833 - val_loss: 1.1601 - val_mae: 0.7961
# Epoch 972/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7140 - mae: 0.6684 - val_loss: 1.1049 - val_mae: 0.7722
# Epoch 973/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7603 - mae: 0.6887 - val_loss: 1.0974 - val_mae: 0.7729
# Epoch 974/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7316 - mae: 0.6725 - val_loss: 1.2985 - val_mae: 0.8455
# Epoch 975/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7288 - mae: 0.6812 - val_loss: 1.1897 - val_mae: 0.8115
# Epoch 976/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8391 - mae: 0.7209 - val_loss: 1.1187 - val_mae: 0.7850
# Epoch 977/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8183 - mae: 0.7059 - val_loss: 1.0748 - val_mae: 0.7599
# Epoch 978/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7274 - mae: 0.6628 - val_loss: 1.1217 - val_mae: 0.7854
# Epoch 979/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7308 - mae: 0.6629 - val_loss: 1.1056 - val_mae: 0.7759
# Epoch 980/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8982 - mae: 0.7003 - val_loss: 1.1196 - val_mae: 0.7859
# Epoch 981/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7086 - mae: 0.6536 - val_loss: 1.3221 - val_mae: 0.8440
# Epoch 982/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8295 - mae: 0.7105 - val_loss: 1.1301 - val_mae: 0.7863
# Epoch 983/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7214 - mae: 0.6636 - val_loss: 1.1457 - val_mae: 0.7928
# Epoch 984/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7560 - mae: 0.6691 - val_loss: 1.1607 - val_mae: 0.8060
# Epoch 985/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7694 - mae: 0.6674 - val_loss: 1.4223 - val_mae: 0.8815
# Epoch 986/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7446 - mae: 0.6816 - val_loss: 1.2868 - val_mae: 0.8348
# Epoch 987/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8032 - mae: 0.7028 - val_loss: 1.0811 - val_mae: 0.7572
# Epoch 988/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7436 - mae: 0.6795 - val_loss: 1.1072 - val_mae: 0.7745
# Epoch 989/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7430 - mae: 0.6844 - val_loss: 1.2343 - val_mae: 0.8226
# Epoch 990/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6924 - mae: 0.6587 - val_loss: 1.1251 - val_mae: 0.7834
# Epoch 991/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7186 - mae: 0.6774 - val_loss: 1.1074 - val_mae: 0.7742
# Epoch 992/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7886 - mae: 0.6925 - val_loss: 1.1026 - val_mae: 0.7810
# Epoch 993/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7730 - mae: 0.6675 - val_loss: 1.1454 - val_mae: 0.7973
# Epoch 994/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6667 - mae: 0.6469 - val_loss: 1.0700 - val_mae: 0.7602
# Epoch 995/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8704 - mae: 0.6990 - val_loss: 1.2417 - val_mae: 0.8261
# Epoch 996/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7474 - mae: 0.6669 - val_loss: 1.1364 - val_mae: 0.7863
# Epoch 997/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7091 - mae: 0.6678 - val_loss: 1.1109 - val_mae: 0.7775
# Epoch 998/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7491 - mae: 0.6956 - val_loss: 1.1291 - val_mae: 0.7887
# Epoch 999/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7896 - mae: 0.6952 - val_loss: 1.0924 - val_mae: 0.7643
# Epoch 1000/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7126 - mae: 0.6529 - val_loss: 1.2007 - val_mae: 0.8074
# Done!

# %% [markdown]
# ## Convert the Tensorflow Model to Tensorflow Lite Model

# %%
# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)
# Out:
# 2532

# %% [markdown]
# ## Predict

# %% [markdown]
# ### Predict with Tensorflow Model

# %%
# Use the model to make predictions from our test data

############################################################
#@markdown How to use the model to predict the result with the test data (`x_test`) and save the result in a variable `predictions`?
script = "predictions = y_test" #@param {type:"string"}
exec(script)
############################################################

# %% [markdown]
# ### Predict with Tensorflow Lite Model

# %%
# Use the Tensorflow lite model to make interfences from our test data
#@markdown Please choose and fill in correct code statements from one of the following:
#@markdown 1. interpreter.invoke() 
#@markdown 2. interpreter_input().fill(x_test[i])
#@markdown 3. interpreter = tf.lite.Interpreter('model.tflite')
#@markdown 4. interpreter_predictions[i] = interpreter_output()[0]
#@markdown 5. interpreter_output = interpreter.tensor(interpreter.get_output_details()[0]["index"])
#@markdown 6. interpreter_input = interpreter.tensor(interpreter.get_input_details()[0]["index"])

############################################################
# Instantiate an interpreter for the TFLite model
#@markdown Which is the statement to instantiate an interpreter with a TFLite Model named `model.tflite`?
script_1 = "interpreter = tf.lite.Interpreter('model.tflite')" #@param {type:"string"}
exec(script_1)
############################################################

# Allocate memory for the model
interpreter.allocate_tensors()

############################################################
# Get the input tensors so we can feed in values 
#@markdown Which is the statement to get input sensors?
script_2 = "interpreter_input = interpreter.tensor(interpreter.get_input_details()[0][\"index\"])" #@param {type:"string"}
exec(script_2)
############################################################

############################################################
# Get the output tensors so we can get the results
#@markdown Which is the statement to get output sensors?
script_3 = "interpreter_output = interpreter.tensor(interpreter.get_output_details()[0][\"index\"])" #@param {type:"string"}
exec(script_3)
############################################################

# Create arrays to store the results
interpreter_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  ############################################################
  #@markdown Which is the statement to fill the input of the interpreter with `x_test[i]`?
  script_4 = "interpreter_input().fill(x_test[i])" #@param {type:"string"}
  exec(script_4)
  ############################################################
  ############################################################
  #@markdown Which is the statement to invoke the interpreter?
  script_5 = "interpreter.invoke()" #@param {type:"string"}
  exec(script_5)
  ############################################################
  ############################################################
  #@markdown Which is the statement to get the output from the interpreter and save the output in `interpreter_predictions[i]`?
  script_6 = "interpreter_predictions[i] = interpreter_output()[0]"#@param {type:"string"}
  exec(script_6)
  ############################################################


# Make the shape of the y_test be the same as the predictions
y_test = np.reshape(y_test, predictions.shape)
# Make the shape of the interpreter_predictions be the same as the predictions
interpreter_predictions = np.reshape(interpreter_predictions, predictions.shape)

# %% [markdown]
# ## Plot the Result

# %%
plt.clf()
plt.title('Test data predicted vs actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted (tensorflow)')
############################################################
#@markdown Please write the statement to plot the outputs in green dots with a label `Predicted (tflite)` from the interpreter.
script = "plt.plot(x_test, interpreter_predictions, 'g.', label='Predicted (tflite)')"#@param {type:"string"}
exec(script)
############################################################
plt.legend()
plt.show()
